# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('/Users/mr.ravirajkumar/Documents/BigMart/Train.csv')

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sns.heatmap(train.isnull(), yticklabels= False, cbar = False, cmap = 'viridis')

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sns.distplot(train['Item_MRP'], kde = False, bins = 100)

# %%
sns.distplot(train['Item_Weight'], kde = False, bins = 50)

# %%
train.groupby(["Item_Type"]).sum().sort_values("Item_MRP", ascending=False)
# Out:
#                        Item_Weight  Item_Visibility     Item_MRP  \
# Item_Type
# Fruits and Vegetables    13476.040        84.407946  178124.0810
# Snack Foods              12832.025        80.220267  175433.9204
# Household                10159.015        55.803305  135976.5254
# Frozen Foods              9238.550        56.192325  118558.8814
# Dairy                     7599.155        49.395349  101276.4596
# Canned                    6632.775        44.215926   90706.7270
# Baking Goods              6580.530        44.821706   81894.7364
# Health and Hygiene        5651.195        28.712309   68025.8388
# Meat                      4319.445        26.470620   59449.8638
# Soft Drinks               4430.950        28.467650   58514.1650
# Breads                    2314.775        16.630030   35379.1198
# Hard Drinks               2086.260        13.897707   29334.6766
# Others                    1897.900        10.180734   22451.8916
# ...

# %%
train.plot.scatter(x = 'Item_Weight', y = 'Item_MRP')

# %%
train['Item_MRP'].plot.density()

# %%
train.plot.bar(stacked = True, figsize=(12,3))

# %%
train.plot.density()

# %%
sns.pairplot(train)

# %%
corr = train.corr()

# %%
sns.jointplot(x = train['Item_MRP'], y = train['Item_Weight'], data = train, kind = 'kde')

# %%
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(corr, cmap = 'coolwarm', annot= True)

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x ='Item_MRP', data = train)

# %%
sns.jointplot(x = train['Item_MRP'], y = train['Item_Weight'])

# %%
train['Item_MRP'].hist(bins = 50, figsize = (12,5))

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import iplot
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
train['Item_MRP'].iplot(kind = 'hist', bins = 50)
# Out:
# <div>
#
#
#             <div id="47caeb2b-b361-4b70-b897-152dc7cab5f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("47caeb2b-b361-4b70-b897-152dc7cab5f5")) {
#                     Plotly.newPlot(
#                         '47caeb2b-b361-4b70-b897-152dc7cab5f5',
# ...

# %%
train['Item_Weight'].iplot(kind = 'hist', bins = 50)
# Out:
# <div>
#
#
#             <div id="3cceaf4b-d9ea-4870-872d-cd09a396389e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3cceaf4b-d9ea-4870-872d-cd09a396389e")) {
#                     Plotly.newPlot(
#                         '3cceaf4b-d9ea-4870-872d-cd09a396389e',
# ...

# %%
group = train.groupby(['Item_Identifier']).sum()

# %%
group
# Out:
#                  Item_Weight  Item_Visibility   Item_MRP  \
# Item_Identifier
# DRA12                 69.600         0.191737   851.1924
# DRA24                 96.750         0.336436  1148.6076
# DRA59                 49.620         1.077744  1481.4392
# DRB01                 14.780         0.246379   568.7590
# DRB13                 30.575         0.040012   948.4650
# ...                      ...              ...        ...
# NCZ30                 39.540         0.174693   845.2686
# NCZ41                 99.250         0.258114   628.1520
# NCZ42                 52.500         0.045222  1183.2240
# NCZ53                 38.400         0.138877   941.6070
# NCZ54                 73.250         0.562983  1135.7864
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Identifier
# DRA12                                12007         11061.6012
# DRA24                                13965         15723.5328
# ...

# %%
group.sort_values('Item_Weight', axis=0, ascending=True, inplace=False)
# Out:
#                  Item_Weight  Item_Visibility   Item_MRP  \
# Item_Identifier
# FDE52                   0.00         0.029742    88.9514
# FDQ60                   0.00         0.191501   121.2098
# FDN52                   0.00         0.130933    86.9198
# FDK57                   0.00         0.079904   120.0440
# NCT53                   5.40         0.132634   492.2578
# ...                      ...              ...        ...
# FDY57                 141.40         0.850270   671.9264
# FDO19                 141.60         0.143986   436.2306
# FDX31                 142.45         0.113826  2104.4622
# FDG09                 164.80         0.464083  1685.0004
# DRE49                 166.00         0.163333  1372.2216
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Identifier
# FDE52                                 1985          3453.5046
# FDQ60                                 1985           120.5098
# ...

# %%
train.mean()
# Out:
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %%
train['Item_Weight'] = train['Item_Weight'].fillna((train['Item_Weight'].mean()))

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Linear Regression Model

# %%
X = train[[ 'Item_Weight', 'Item_Visibility', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']]

# %%
y = train['Item_MRP']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -413.0340878003275

# %%
lm.coef_
# Out:
# array([2.14279157e-01, 1.04982824e+02, 2.50058050e-01, 2.07886847e-02])

# %%
cdf= pd.DataFrame(lm.coef_, X.columns, columns = ['Coeff'])

# %%
cdf
# Out:
#                                 Coeff
# Item_Weight                  0.214279
# Item_Visibility            104.982824
# Outlet_Establishment_Year    0.250058
# Item_Outlet_Sales            0.020789

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([116.29081787, 149.89916299, 136.31683015, ...,  89.06079165,
#        167.64226807, 108.19858686])

# %%
y_test
# Out:
# 8179    100.3358
# 8355    148.6418
# 3411     77.5986
# 7089     39.9506
# 6954    152.9340
#           ...
# 4939    128.1020
# 767      82.1908
# 7734     38.7480
# 6708     93.8094
# 586      83.8250
# Name: Item_MRP, Length: 3410, dtype: float64

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot(y_test-predictions, bins = 100)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
# Out:
# MAE: 41.10684553834728

# %%
print('MSE:', metrics.mean_squared_error(y_test, predictions))
# Out:
# MSE: 2548.9047664638942

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 50.48667909918313

# %%
print(X_test.tail(), [predictions[i] for i in range(len(predictions)-1, len(predictions)-6,-1)])
print(y_test.tail())
# Out:
#       Item_Weight  Item_Visibility  Outlet_Establishment_Year  \
# 4939    19.850000         0.045631                       1987
# 767     19.250000         0.058366                       1999
# 7734    12.857645         0.012512                       1985
# 6708    12.857645         0.135837                       1985
# 586      9.395000         0.045362                       2002
#
#       Item_Outlet_Sales
# 4939          1265.0200
# 767           2432.8332
# 7734            79.8960
# 6708          3237.1196
# 586            665.8000   [108.19858686327427, 167.642268073443, 89.06079165451126, 147.65962653069573, 119.1732959227545]
# 4939    128.1020
# 767      82.1908
# 7734     38.7480
# 6708     93.8094
# 586      83.8250
# Name: Item_MRP, dtype: float64
